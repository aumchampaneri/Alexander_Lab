# %% [markdown]
# Download Tabula Sapiens from CellxGENE
# - 1.1 Million Cells
# - 42.0 GB -> Subset to only the datasets needed
# - 7 Datasets (Neural, Eye, Blood, Vasculature, Endothelial, Immune)

# %%
import cellxgene_census

# Run each import separately to avoid kernel crash

cellxgene_census.download_source_h5ad(
    "6e4acdae-59ef-452b-a6d4-260cba368586", to_path="Tabula_Sapiens_Neural.h5ad"
)

# cellxgene_census.download_source_h5ad(
#     "a0754256-f44b-4c4a-962c-a552e47d3fdc", to_path="Tabula_Sapiens_Eye.h5ad"
# )
#
# cellxgene_census.download_source_h5ad(
#     "983d5ec9-40e8-4512-9e65-a572a9c486cb", to_path="Tabula_Sapiens_Blood.h5ad"
# )
#
# cellxgene_census.download_source_h5ad(
#     "a2d4d33e-4c62-4361-b80a-9be53d2e50e8", to_path="Tabula_Sapiens_Vasculature.h5ad"
# )
#
# cellxgene_census.download_source_h5ad(
#     "5a11f879-d1ef-458a-910c-9b0bdfca5ebf", to_path="Tabula_Sapiens_Endothelial.h5ad"
# )
#
# cellxgene_census.download_source_h5ad(
#     "c5d88abe-f23a-45fa-a534-788985e93dad", to_path="Tabula_Sapiens_Immune.h5ad"
# )
# Out:
# Downloading:   0%|          | 0.00/125M [00:00<?, ?B/s]
#
# Downloading:   0%|          | 86.2k/125M [00:00<03:34, 609kB/s]
#
# Downloading:   0%|          | 409k/125M [00:00<01:20, 1.62MB/s]
#
# Downloading:   1%|          | 885k/125M [00:00<00:46, 2.81MB/s]
#
# Downloading:   1%|          | 1.46M/125M [00:00<00:40, 3.22MB/s]
#
# Downloading:   2%|▏         | 2.37M/125M [00:00<00:25, 4.99MB/s]
#
# Downloading:   2%|▏         | 3.12M/125M [00:00<00:21, 5.81MB/s]
#
# Downloading:   3%|▎         | 3.93M/125M [00:00<00:21, 6.01MB/s]
#
# Downloading:   4%|▍         | 4.73M/125M [00:01<00:19, 6.31MB/s]
#
# Downloading:   4%|▍         | 5.49M/125M [00:01<00:18, 6.76MB/s]
#
# Downloading:   5%|▍         | 6.18M/125M [00:01<00:21, 5.66MB/s]
#
# Downloading:   5%|▌         | 6.80M/125M [00:01<00:21, 5.87MB/s]
#
# Downloading:   6%|▌         | 7.45M/125M [00:01<00:20, 6.07MB/s]
#
# Downloading:   6%|▋         | 8.10M/125M [00:01<00:22, 5.33MB/s]
#
# ...

# %% [markdown]
# Proposed Analysis
# - Complement expression in each dataset
#     - Use the Ensembl_codes.py as reference to poll genes
# - Complement expression in one graph with each dataset
# - Complement expression across datasets for each cell type listed == heat map
# - Try clustering?
# - Maybe some PCA?
# - Maybe some tSNE?
# - Maybe some UMAP?
# - Maybe use R for speed?
